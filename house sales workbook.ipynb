# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
df1 = pd.read_csv('/Users/Luke-Workstation/documents/housesales.csv')

# %%
df1.shape
# Out:
# (21613, 21)

# %%
print(df1.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df1.columns # Read the columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
print(df1['waterfront']) #print the individual column names
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 21608    0
# 21609    0
# 21610    0
# 21611    0
# 21612    0
# Name: waterfront, Length: 21613, dtype: int64

# %%
df1.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  20479.000000  20545.000000  20503.000000
# mean   4.580302e+09  5.400881e+05      3.372821      2.113507   2081.073697
# std    2.876566e+09  3.671272e+05      0.930711      0.768913    915.043176
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.500000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1920.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  12050.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.056900e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.517982e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
print(df1['sqft_living'].isnull())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: sqft_living, Length: 21613, dtype: bool

# %%
# used the cut command to bin the grade values into 3 groups

df1['grade_bin']=pd.cut(df1['grade'],3,labels=['Group 1','Group 2 ','Group 3'])

# %%
#use the value_counts to see the counts for the values in the grade_bin
df1['grade_bin'].value_counts()
# Out:
# Group 2     19702
# Group 3      1636
# Group 1       275
# Name: grade_bin, dtype: int64

# %%
19702+1636+275
# Out:
# 21613

# %%
275/21613*100
# Out:
# 1.2723823624670336

# %%
19702/21613*100
# Out:
# 91.15809929209271

# %%
1636/21613*100
# Out:
# 7.569518345440245

# %%
df1.set_index(['grade_bin'])['sqft_living'].fillna(df1['sqft_living'].median(), inplace=True)

# %%
df1.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         20479
# bathrooms        20545
# sqft_living      20503
# sqft_lot         20569
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# grade_bin        21613
# dtype: int64

# %%
df1.describe(include=['O'])
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
df1_boxplot = df1[['sqft_living', 'sqft_above', 'sqft_basement', 'sqft_living15']]
df1_barplot = df1[['bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'grade_bin']]

# %%
for i in df1_barplot.columns:
    plt.figure(figsize=(10,5))
    cat_num = df1[i].value_counts()
    sns.barplot(x=cat_num.index, y=cat_num)
    plt.show()

# %%
sns.set()
plt.figure(figsize=(18,8))
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>
